# %% [markdown]
# ## Principles and Applications of Data Science (Spring 2022)
# ## Homework 2
# ## Due: Jun 15, 2022
#
# ### Name:
# ### Student ID Number:

# %% [markdown]
# ### Homework Description
# This assignment is to practice creating a bar graph grid using the tool such as MatPlotLib with Taipei’s traffic accident data from year 101 (2012) to 108 (2019). The files we provide are the data files (xxxTraffic accident.csv) of eight years and a correspondence table for mapping codes to certain fields (Traffic accident chart.csv). In the data file, there are fifteen attributes, including ***Year, Month, Day, Hour, Minute, Processing class, death toll, Injuries Person, Vehicle type, Sex, Age, Weather, Speed limit, Road pattern, Accident location***. With the data files and table, your homework should be done according to the following **requirements**:
#
# #### There are six main topics to be shown in each year:
#    <font color=green> 1. Number of traffic accident death toll per month <br>
#    2. Number of traffic accident injuries per month <br>
#    3. Number of traffic accident injuries per vehicle type (take the top 10) <br>
#    4. Number of traffic accident injuries per weather <br>
#    5. Number of traffic accident injuries per road pattern (take the top 10) <br>
#    6. Number of traffic accident injuries per accident location (take the top 10) <br>
#    </font>
# #### Each topic will be presented by a bar chart.
# #### For each year, use bar graph grid to show the six topics. Thus, there will be eight grids for years and each grid has six bar charts for each topic.
#
# #### On the other hand, please produce the grids for the six topics respectively. Each grid will have eight bar charts for the eight years.
#
# #### Please do not forget, in each chart, to have the topic on the top and label the x-axis and y-axis.
# #### Sample:
#
# **<font color=green size=2> Year: 101 </font>**
# ![HW2sample_1.png](HW2sample_1.png)
# **<font color=green size=2> Topic: top 10 Accident_location </font>**
# ![HW2sample_2.png](HW2sample_2.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 讀取 CSV File
import pandas as pd # 引用套件並縮寫為 pd  
df = pd.read_csv('101Traffic_accident.csv')  
#print(df)  
df
# Out:
#        Year  Month  Day  Hour  Minute  Processing_class  death_toll  \
# 0       101     10    3    10      40                 2           0
# 1       101     10    3    10      40                 2           0
# 2       101      1   29    12      30                 2           0
# 3       101      1   29    12      30                 2           0
# 4       101      2    2    23      50                 2           0
# ...     ...    ...  ...   ...     ...               ...         ...
# 45945   101     11   26    17      10                 2           0
# 45946   101     11    2    17      29                 2           0
# 45947   101     11    2    17      29                 2           0
# 45948   101      5    7    20       0                 2           0
# 45949   101      5    7    20       0                 2           0
#
#        Injuries_Person Vehicle_type  Sex   Age  Weather  Speed_limit  \
# 0                    1          B03    1  30.0      8.0            0
# ...

# %%
#df.sort_values(["death_toll"], ascending=False).head(20)

y = list(df["death_toll"])
x = list(df["Month"])
#print(y)
#print(x)

plt.bar(x,y)
#plt.bar(df["death_toll"], df["Month"])

plt.title('101 death toll (month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Death_toll')  #y軸說明文字


plt.show()

# %%
y2 = list(df["Injuries_Person"])
x2 = list(df["Month"])

plt.bar(x2, y2)

#plt.title('101 Injuries_Person (Month)')  #圖表標題
#plt.xlabel('Month')  #x軸說明文字
#plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

# %%
#df = df['Vehicle_type'].astype(str) 


y3 = list(df["Injuries_Person"])
x3 = list(df["Vehicle_type"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Vehicle_type)')  #圖表標題
plt.xlabel('Vehicle_type')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

# %%
y4 = list(df["Injuries_Person"])
x4 = list(df["Weather"])

#plt.bar(df["Injuries_Person"], df["Weather"])

plt.bar(x4, y4)
plt.title('101 Injuries_Person (Weather)')  #圖表標題
plt.xlabel('Weather')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

# %%
y5 = list(df["Injuries_Person"])
x5 = list(df["Road_pattern"])

#plt.bar(df["Injuries_Person"], df["Road_pattern"])
plt.bar(x5, y5)

plt.title('101 Injuries_Person (Road_pattern)')  #圖表標題
plt.xlabel('Road_pattern')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

# %%
y6 = list(df["Injuries_Person"])
x6 = list(df["Accident_location"])

#plt.bar(df["Injuries_Person"], df["Accident_location"])
plt.bar(x6, y6)

plt.title('101 Injuries_Person (Accident_location)')  #圖表標題
plt.xlabel('Accident_location')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

# %% [markdown]
# # This is 101

# %%
#102Traffic_accident.csv

import numpy as np
import matplotlib.pyplot as plt
# 讀取 CSV File
import pandas as pd # 引用套件並縮寫為 pd  
df = pd.read_csv('101Traffic_accident.csv')  
#print(df)  
#df


#作圖
#1
y = list(df["death_toll"])
x = list(df["Month"])
#print(y)
#print(x)

plt.bar(x,y)
#plt.bar(df["death_toll"], df["Month"])

plt.title('101 death toll (month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Death_toll')  #y軸說明文字

plt.show()

#2
y2 = list(df["Injuries_Person"])
x2 = list(df["Month"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#3
y3 = list(df["Injuries_Person"])
x3 = list(df["Vehicle_type"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Vehicle_type)')  #圖表標題
plt.xlabel('Vehicle_type')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#4
y4 = list(df["Injuries_Person"])
x4 = list(df["Weather"])

#plt.bar(df["Injuries_Person"], df["Weather"])

plt.bar(x4, y4)
plt.title('101 Injuries_Person (Weather)')  #圖表標題
plt.xlabel('Weather')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#5
y5 = list(df["Injuries_Person"])
x5 = list(df["Road_pattern"])

#plt.bar(df["Injuries_Person"], df["Road_pattern"])
plt.bar(x5, y5)

plt.title('101 Injuries_Person (Road_pattern)')  #圖表標題
plt.xlabel('Road_pattern')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#6
y6 = list(df["Injuries_Person"])
x6 = list(df["Accident_location"])

#plt.bar(df["Injuries_Person"], df["Accident_location"])
plt.bar(x6, y6)

plt.title('101 Injuries_Person (Accident_location)')  #圖表標題
plt.xlabel('Accident_location')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字


plt.show()

# %% [markdown]
# # This is 102

# %%
import numpy as np
import matplotlib.pyplot as plt
# 讀取 CSV File
import pandas as pd # 引用套件並縮寫為 pd  
df = pd.read_csv('102Traffic_accident.csv')  
#print(df)  
#df


#作圖
#1
y = list(df["death_toll"])
x = list(df["Month"])
#print(y)
#print(x)

plt.bar(x,y)
#plt.bar(df["death_toll"], df["Month"])

plt.title('101 death toll (month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Death_toll')  #y軸說明文字

plt.show()

#2
y2 = list(df["Injuries_Person"])
x2 = list(df["Month"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#3
y3 = list(df["Injuries_Person"])
x3 = list(df["Vehicle_type"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Vehicle_type)')  #圖表標題
plt.xlabel('Vehicle_type')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#4
y4 = list(df["Injuries_Person"])
x4 = list(df["Weather"])

#plt.bar(df["Injuries_Person"], df["Weather"])

plt.bar(x4, y4)
plt.title('101 Injuries_Person (Weather)')  #圖表標題
plt.xlabel('Weather')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#5
y5 = list(df["Injuries_Person"])
x5 = list(df["Road_pattern"])

#plt.bar(df["Injuries_Person"], df["Road_pattern"])
plt.bar(x5, y5)

plt.title('101 Injuries_Person (Road_pattern)')  #圖表標題
plt.xlabel('Road_pattern')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#6
y6 = list(df["Injuries_Person"])
x6 = list(df["Accident_location"])

#plt.bar(df["Injuries_Person"], df["Accident_location"])
plt.bar(x6, y6)

plt.title('101 Injuries_Person (Accident_location)')  #圖表標題
plt.xlabel('Accident_location')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字


plt.show()

# %% [markdown]
# # This is 103

# %%
import numpy as np
import matplotlib.pyplot as plt
# 讀取 CSV File
import pandas as pd # 引用套件並縮寫為 pd  
df = pd.read_csv('103Traffic_accident.csv')  

#作圖
#1
y = list(df["death_toll"])
x = list(df["Month"])

plt.bar(x,y)

plt.title('101 death toll (month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Death_toll')  #y軸說明文字

plt.show()

#2
y2 = list(df["Injuries_Person"])
x2 = list(df["Month"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#3
y3 = list(df["Injuries_Person"])
x3 = list(df["Vehicle_type"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Vehicle_type)')  #圖表標題
plt.xlabel('Vehicle_type')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#4
y4 = list(df["Injuries_Person"])
x4 = list(df["Weather"])

#plt.bar(df["Injuries_Person"], df["Weather"])

plt.bar(x4, y4)
plt.title('101 Injuries_Person (Weather)')  #圖表標題
plt.xlabel('Weather')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#5
y5 = list(df["Injuries_Person"])
x5 = list(df["Road_pattern"])

#plt.bar(df["Injuries_Person"], df["Road_pattern"])
plt.bar(x5, y5)

plt.title('101 Injuries_Person (Road_pattern)')  #圖表標題
plt.xlabel('Road_pattern')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#6
y6 = list(df["Injuries_Person"])
x6 = list(df["Accident_location"])

#plt.bar(df["Injuries_Person"], df["Accident_location"])
plt.bar(x6, y6)

plt.title('101 Injuries_Person (Accident_location)')  #圖表標題
plt.xlabel('Accident_location')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字


plt.show()

# %% [markdown]
# # This is 104

# %%
import numpy as np
import matplotlib.pyplot as plt
# 讀取 CSV File
import pandas as pd # 引用套件並縮寫為 pd  
df = pd.read_csv('104Traffic_accident.csv')  

#作圖
#1
y = list(df["death_toll"])
x = list(df["Month"])

plt.bar(x,y)

plt.title('101 death toll (month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Death_toll')  #y軸說明文字

plt.show()

#2
y2 = list(df["Injuries_Person"])
x2 = list(df["Month"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#3
y3 = list(df["Injuries_Person"])
x3 = list(df["Vehicle_type"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Vehicle_type)')  #圖表標題
plt.xlabel('Vehicle_type')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#4
y4 = list(df["Injuries_Person"])
x4 = list(df["Weather"])

#plt.bar(df["Injuries_Person"], df["Weather"])

plt.bar(x4, y4)
plt.title('101 Injuries_Person (Weather)')  #圖表標題
plt.xlabel('Weather')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#5
y5 = list(df["Injuries_Person"])
x5 = list(df["Road_pattern"])

#plt.bar(df["Injuries_Person"], df["Road_pattern"])
plt.bar(x5, y5)

plt.title('101 Injuries_Person (Road_pattern)')  #圖表標題
plt.xlabel('Road_pattern')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#6
y6 = list(df["Injuries_Person"])
x6 = list(df["Accident_location"])

#plt.bar(df["Injuries_Person"], df["Accident_location"])
plt.bar(x6, y6)

plt.title('101 Injuries_Person (Accident_location)')  #圖表標題
plt.xlabel('Accident_location')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字


plt.show()

# %% [markdown]
# # This is 105

# %%
import numpy as np
import matplotlib.pyplot as plt
# 讀取 CSV File
import pandas as pd # 引用套件並縮寫為 pd  
df = pd.read_csv('105Traffic_accident.csv')  

#作圖
#1
y = list(df["death_toll"])
x = list(df["Month"])

plt.bar(x,y)

plt.title('101 death toll (month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Death_toll')  #y軸說明文字

plt.show()

#2
y2 = list(df["Injuries_Person"])
x2 = list(df["Month"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#3
y3 = list(df["Injuries_Person"])
x3 = list(df["Vehicle_type"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Vehicle_type)')  #圖表標題
plt.xlabel('Vehicle_type')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#4
y4 = list(df["Injuries_Person"])
x4 = list(df["Weather"])

#plt.bar(df["Injuries_Person"], df["Weather"])

plt.bar(x4, y4)
plt.title('101 Injuries_Person (Weather)')  #圖表標題
plt.xlabel('Weather')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#5
y5 = list(df["Injuries_Person"])
x5 = list(df["Road_pattern"])

#plt.bar(df["Injuries_Person"], df["Road_pattern"])
plt.bar(x5, y5)

plt.title('101 Injuries_Person (Road_pattern)')  #圖表標題
plt.xlabel('Road_pattern')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#6
y6 = list(df["Injuries_Person"])
x6 = list(df["Accident_location"])

#plt.bar(df["Injuries_Person"], df["Accident_location"])
plt.bar(x6, y6)

plt.title('101 Injuries_Person (Accident_location)')  #圖表標題
plt.xlabel('Accident_location')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字


plt.show()

# %% [markdown]
# # This is 106

# %%
import numpy as np
import matplotlib.pyplot as plt
# 讀取 CSV File
import pandas as pd # 引用套件並縮寫為 pd  
df = pd.read_csv('106Traffic_accident.csv')  

#作圖
#1
y = list(df["death_toll"])
x = list(df["Month"])

plt.bar(x,y)

plt.title('101 death toll (month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Death_toll')  #y軸說明文字

plt.show()

#2
y2 = list(df["Injuries_Person"])
x2 = list(df["Month"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#3
y3 = list(df["Injuries_Person"])
x3 = list(df["Vehicle_type"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Vehicle_type)')  #圖表標題
plt.xlabel('Vehicle_type')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#4
y4 = list(df["Injuries_Person"])
x4 = list(df["Weather"])

#plt.bar(df["Injuries_Person"], df["Weather"])

plt.bar(x4, y4)
plt.title('101 Injuries_Person (Weather)')  #圖表標題
plt.xlabel('Weather')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#5
y5 = list(df["Injuries_Person"])
x5 = list(df["Road_pattern"])

#plt.bar(df["Injuries_Person"], df["Road_pattern"])
plt.bar(x5, y5)

plt.title('101 Injuries_Person (Road_pattern)')  #圖表標題
plt.xlabel('Road_pattern')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#6
y6 = list(df["Injuries_Person"])
x6 = list(df["Accident_location"])

#plt.bar(df["Injuries_Person"], df["Accident_location"])
plt.bar(x6, y6)

plt.title('101 Injuries_Person (Accident_location)')  #圖表標題
plt.xlabel('Accident_location')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字


plt.show()

# %% [markdown]
# # This is 107

# %%
import numpy as np
import matplotlib.pyplot as plt
# 讀取 CSV File
import pandas as pd # 引用套件並縮寫為 pd  
df = pd.read_csv('107Traffic_accident.csv')  

#作圖
#1
y = list(df["death_toll"])
x = list(df["Month"])

plt.bar(x,y)

plt.title('101 death toll (month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Death_toll')  #y軸說明文字

plt.show()

#2
y2 = list(df["Injuries_Person"])
x2 = list(df["Month"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#3
y3 = list(df["Injuries_Person"])
x3 = list(df["Vehicle_type"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Vehicle_type)')  #圖表標題
plt.xlabel('Vehicle_type')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#4
y4 = list(df["Injuries_Person"])
x4 = list(df["Weather"])

#plt.bar(df["Injuries_Person"], df["Weather"])

plt.bar(x4, y4)
plt.title('101 Injuries_Person (Weather)')  #圖表標題
plt.xlabel('Weather')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#5
y5 = list(df["Injuries_Person"])
x5 = list(df["Road_pattern"])

#plt.bar(df["Injuries_Person"], df["Road_pattern"])
plt.bar(x5, y5)

plt.title('101 Injuries_Person (Road_pattern)')  #圖表標題
plt.xlabel('Road_pattern')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#6
y6 = list(df["Injuries_Person"])
x6 = list(df["Accident_location"])

#plt.bar(df["Injuries_Person"], df["Accident_location"])
plt.bar(x6, y6)

plt.title('101 Injuries_Person (Accident_location)')  #圖表標題
plt.xlabel('Accident_location')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字


plt.show()

# %% [markdown]
# # This is 108

# %%
import numpy as np
import matplotlib.pyplot as plt
# 讀取 CSV File
import pandas as pd # 引用套件並縮寫為 pd  
df = pd.read_csv('108Traffic_accident.csv')  

#作圖
#1
y = list(df["death_toll"])
x = list(df["Month"])

plt.bar(x,y)

plt.title('101 death toll (month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Death_toll')  #y軸說明文字

plt.show()

#2
y2 = list(df["Injuries_Person"])
x2 = list(df["Month"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Month)')  #圖表標題
plt.xlabel('Month')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#3
y3 = list(df["Injuries_Person"])
x3 = list(df["Vehicle_type"])

plt.bar(x2, y2)

plt.title('101 Injuries_Person (Vehicle_type)')  #圖表標題
plt.xlabel('Vehicle_type')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#4
y4 = list(df["Injuries_Person"])
x4 = list(df["Weather"])

#plt.bar(df["Injuries_Person"], df["Weather"])

plt.bar(x4, y4)
plt.title('101 Injuries_Person (Weather)')  #圖表標題
plt.xlabel('Weather')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#5
y5 = list(df["Injuries_Person"])
x5 = list(df["Road_pattern"])

#plt.bar(df["Injuries_Person"], df["Road_pattern"])
plt.bar(x5, y5)

plt.title('101 Injuries_Person (Road_pattern)')  #圖表標題
plt.xlabel('Road_pattern')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字

plt.show()

#6
y6 = list(df["Injuries_Person"])
x6 = list(df["Accident_location"])

#plt.bar(df["Injuries_Person"], df["Accident_location"])
plt.bar(x6, y6)

plt.title('101 Injuries_Person (Accident_location)')  #圖表標題
plt.xlabel('Accident_location')  #x軸說明文字
plt.ylabel('Injuries_Person')  #y軸說明文字


plt.show()
